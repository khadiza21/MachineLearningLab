# %% [markdown]
# <a href="https://colab.research.google.com/github/khadiza21/MachineLearningLab/blob/main/labFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn as sl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
from pandas import read_csv
snails = '/content/snails.csv'
columns = ['Sex', 'Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']
df = read_csv(snails , names = columns)
print(df.shape)
# Out:
# (4177, 9)

# %%
df.head(20)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.455     0.365   0.095        0.5140          0.2245
# 1    M   0.350     0.265   0.090        0.2255          0.0995
# 2    F   0.530     0.420   0.135        0.6770          0.2565
# 3    M   0.440     0.365   0.125        0.5160          0.2155
# 4    I   0.330     0.255   0.080        0.2050          0.0895
# 5    I   0.425     0.300   0.095        0.3515          0.1410
# 6    F   0.530     0.415   0.150        0.7775          0.2370
# 7    F   0.545     0.425   0.125        0.7680          0.2940
# 8    M   0.475     0.370   0.125        0.5095          0.2165
# 9    F   0.550     0.440   0.150        0.8945          0.3145
# 10   F   0.525     0.380   0.140        0.6065          0.1940
# 11   M   0.430     0.350   0.110        0.4060          0.1675
# 12   M   0.490     0.380   0.135        0.5415          0.2175
# 13   F   0.535     0.405   0.145        0.6845          0.2725
# 14   F   0.470     0.355   0.100        0.4755          0.1675
# 15   M   0.500     0.400   0.130        0.6645          0.2580
# 16   I   0.355     0.280   0.085        0.2905          0.0950
# 17   F   0.440     0.340   0.100        0.4510          0.1880
# 18   M   0.365     0.295   0.080        0.2555          0.0970
# 19   M   0.450     0.320   0.100        0.3810          0.1705
#
#     Viscera weight  Shell weight  Rings
# 0           0.1010         0.150     15
# 1           0.0485         0.070      7
# 2           0.1415         0.210      9
# 3           0.1140         0.155     10
# 4           0.0395         0.055      7
# 5           0.0775         0.120      8
# 6           0.1415         0.330     20
# 7           0.1495         0.260     16
# 8           0.1125         0.165      9
# 9           0.1510         0.320     19
# 10          0.1475         0.210     14
# 11          0.0810         0.135     10
# 12          0.0950         0.190     11
# 13          0.1710         0.205     10
# 14          0.0805         0.185     10
# 15          0.1330         0.240     12
# 16          0.0395         0.115      7
# 17          0.0870         0.130     10
# 18          0.0430         0.100      7
# 19          0.0750         0.115      9

# %%
df.shape
# Out:
# (4176, 9)

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4176.000000  4176.000000  4176.000000   4176.000000      4176.00000
# mean      0.524009     0.407892     0.139527      0.828818         0.35940
# std       0.120103     0.099250     0.041826      0.490424         0.22198
# min       0.075000     0.055000     0.000000      0.002000         0.00100
# 25%       0.450000     0.350000     0.115000      0.441500         0.18600
# 50%       0.545000     0.425000     0.140000      0.799750         0.33600
# 75%       0.615000     0.480000     0.165000      1.153250         0.50200
# max       0.815000     0.650000     1.130000      2.825500         1.48800
#
#        Viscera weight  Shell weight        Rings
# count     4176.000000   4176.000000  4176.000000
# mean         0.180613      0.238852     9.932471
# std          0.109620      0.139213     3.223601
# min          0.000500      0.001500     1.000000
# 25%          0.093375      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
X=df.data
y=df.target

X_train , X_test, y_train, y_test = train_test_split(X,y,test_size=20,random_state=4)
y_train = y_train.reshape((y_train.shape[0],1))
y_test = y_test.reshape((y_test.shape[0],1))
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-d7fdc6d64db9> in <cell line: 1>()
# ----> 1 X=df.data
#       2 y=df.target
#       3
#       4 X_train , X_test, y_train, y_test = train_test_split(X,y,test_size=20,random_state=4)
#       5 y_train = y_train.reshape((y_train.shape[0],1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'
