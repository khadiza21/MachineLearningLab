# %% [markdown]
# <a href="https://colab.research.google.com/github/khadiza21/MachineLearningLab/blob/main/studentScores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('/content/student_scores.csv')
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
dataset.plot(x='Hours', y='Scores', style='o')
plt.title('Hours_vs_Percentage')
plt.xlabel('Hours_Studied')
plt.ylabel('Percnetage_Score')
plt.show()

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 2.018160041434662
# [9.91065648]

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual' : y_test, 'Predicted' : y_pred})
df.head()
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
from sklearn import metrics
print ('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error:  21.598769307217456
