# %% [markdown]
# <a href="https://colab.research.google.com/github/khadiza21/epz-tex-4022/blob/main/pima_indians_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn as sl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas import read_csv
pima = '/content/pima-indians-diabetes.csv'
columns = ['preg', 'plas','pres','skin','test','mass','pedi','age','class']
df = read_csv(pima , names = columns)
print(df.shape)
# Out:
# (768, 9)

# %%
df.head(20)
# Out:
#     preg  plas  pres  skin  test  mass   pedi  age  class
# 0      6   148    72    35     0  33.6  0.627   50      1
# 1      1    85    66    29     0  26.6  0.351   31      0
# 2      8   183    64     0     0  23.3  0.672   32      1
# 3      1    89    66    23    94  28.1  0.167   21      0
# 4      0   137    40    35   168  43.1  2.288   33      1
# 5      5   116    74     0     0  25.6  0.201   30      0
# 6      3    78    50    32    88  31.0  0.248   26      1
# 7     10   115     0     0     0  35.3  0.134   29      0
# 8      2   197    70    45   543  30.5  0.158   53      1
# 9      8   125    96     0     0   0.0  0.232   54      1
# 10     4   110    92     0     0  37.6  0.191   30      0
# 11    10   168    74     0     0  38.0  0.537   34      1
# 12    10   139    80     0     0  27.1  1.441   57      0
# 13     1   189    60    23   846  30.1  0.398   59      1
# 14     5   166    72    19   175  25.8  0.587   51      1
# ...

# %%
# removed the first row and make the all value in float
df = df.tail(-1)
df = df.astype(float)

# %%
#viewing dimenssions
df.shape

# %%
#data type of each attribute
df.dtypes

# %%
#statistical summary
df.describe()
# Out:
#              preg        plas        pres  ...        pedi         age       class
# count  767.000000  767.000000  767.000000  ...  767.000000  767.000000  767.000000
# mean     3.842243  120.859192   69.101695  ...    0.471674   33.219035    0.348110
# std      3.370877   31.978468   19.368155  ...    0.331497   11.752296    0.476682
# min      0.000000    0.000000    0.000000  ...    0.078000   21.000000    0.000000
# 25%      1.000000   99.000000   62.000000  ...    0.243500   24.000000    0.000000
# 50%      3.000000  117.000000   72.000000  ...    0.371000   29.000000    0.000000
# 75%      6.000000  140.000000   80.000000  ...    0.625000   41.000000    1.000000
# max     17.000000  199.000000  122.000000  ...    2.420000   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
#distribution of classes
df.groupby('class').size()
