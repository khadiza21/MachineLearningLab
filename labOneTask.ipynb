# %% [markdown]
# <a href="https://colab.research.google.com/github/khadiza21/MachineLearningLab/blob/main/labOneTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
# ploting to our canvas
plt.plot ([1,2.5,3,4.5],[1,2,5,4.5])
# adding title and axis labels
plt.title("Title of the plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# showing what I ploted
plt.show()
